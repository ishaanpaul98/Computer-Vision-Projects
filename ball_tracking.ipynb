# %% [markdown]
# # Imports

# %%
#!pip install imutils
#!pip install opencv-python

# %%
from collections import deque
from imutils.video import VideoStream
import numpy as np
import argparse
import cv2
import imutils
import time

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Tracking Ball

# %%
img = cv2.imread("Dataset/Pictures/train/1.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()
